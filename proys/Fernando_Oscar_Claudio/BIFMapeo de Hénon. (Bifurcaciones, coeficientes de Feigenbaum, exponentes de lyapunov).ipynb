# %%
(2//3)^5
# Out:
# 32//243

# %%
f(x)=(x+1)*(x^(2/3)-1)/(x^(1/5)-1)
# Out:
# f (generic function with 1 method)

# %%
using PyPlot

# %%
0.5^(1/5)
# Out:
# 0.8705505632961241

# %%
xrange=0.5:1/2^8:1.5
# Out:
# 0.5:0.00390625:1.5

# %%
ff=zeros(length(xrange))
[ff[i]=f(xrange[i]) for i in 1:length(xrange)]
plot(xrange,ff);
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x31b28e150>)

# %%
20/3
# Out:
# 6.666666666666667
